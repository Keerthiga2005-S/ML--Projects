# %%
d=pd.read_csv("/content/houseprice - houseprice.csv")

# %%
# !git clone https://github.com/Keerthiga2005-S/ML--Projects.git
# Out:
# Cloning into 'ML--Projects'...
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
d.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0         1
# 1           1  6414100192  20141209T000000       NaN       NaN         ?
# 2           2  5631500400  20150225T000000  180000.0       2.0         1
# 3           3  2487200875  20141209T000000  604000.0       4.0         3
# 4           4  1954400510  20150218T000000  510000.0       3.0         2
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0       1180.0      5650     1.0           0  ...      7        1180
# 1          NaN      7242     2.0           0  ...      7        2170
# 2        770.0     10000     1.0           0  ...      6         770
# 3       1960.0      5000     1.0           0  ...      7        1050
# 4       1680.0      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
d.isna().sum()
# Out:
# Unnamed: 0       0
# id               0
# date             0
# price            1
# bedrooms         1
# bathrooms        0
# sqft_living      1
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
d=d.replace('?',np.nan)

# %%
d=d.fillna(d.mean())
# Out:
# <ipython-input-6-0bc562e9830f>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d=d.fillna(d.mean())

# %%
d=d.dropna()

# %%
x=d[['sqft_living','grade']]
y=d[['price']]

# %%
import seaborn as sns
sns.heatmap(d.corr())
# Out:
# <ipython-input-9-06dd939deb91>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(d.corr())
# <Axes: >

# %%
d.corr()
# Out:
# <ipython-input-10-da7db8af9981>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d.corr()
#                Unnamed: 0        id     price  bedrooms  sqft_living  \
# Unnamed: 0       1.000000  0.006770  0.027374  0.010762     0.044763
# id               0.006770  1.000000 -0.016762  0.001298    -0.012274
# price            0.027374 -0.016762  1.000000  0.308351     0.702040
# bedrooms         0.010762  0.001298  0.308351  1.000000     0.576686
# sqft_living      0.044763 -0.012274  0.702040  0.576686     1.000000
# sqft_lot        -0.026894 -0.132104  0.089661  0.031700     0.172832
# floors           0.179229  0.018498  0.256799  0.175450     0.353936
# waterfront      -0.007619 -0.002719  0.266369 -0.006584     0.103821
# view            -0.013776  0.011602  0.397294  0.079527     0.284621
# ...

# %%
from sklearn.linear_model import LinearRegression
lr1=LinearRegression()
lr1.fit(x.iloc[:,0:1],y)
lr2=LinearRegression()
lr2.fit(x.iloc[:,1:2],y)
# Out:
# LinearRegression()

# %%
#Plotting first feature
import matplotlib.pyplot as plt
plt.scatter(x.iloc[:,0:1],y)
plt.plot(np.array(x.iloc[:,0:1]),lr1.predict(x.iloc[:,0:1]),color = "Black")

# %%
#Plotting second feature
import matplotlib.pyplot as plt
plt.scatter(x.iloc[:,1:2],y)
plt.plot(np.array(x.iloc[:,1:2]),lr2.predict(x.iloc[:,1:2]),color = "black")

# %%
from sklearn.metrics import r2_score,mean_squared_error
print("Mean Sqaure Error Feature 1 : ",mean_squared_error(y,lr1.predict(x.iloc[:,0:1])))
print("Linear Regression Feature 1 R2 Score : ",r2_score(y,lr1.predict(x.iloc[:,0:1])))
print(mean_squared_error(y,lr2.predict(x.iloc[:,1:2])))
print("Mean Sqaure Error Feature 2 : ",r2_score(y,lr2.predict(x.iloc[:,1:2])))
# Out:
# Mean Sqaure Error Feature 1 :  68353547423.153534
# Linear Regression Feature 1 R2 Score :  0.4928599098910641
# 74740234978.0719
# Mean Sqaure Error Feature 2 :  0.44547472764078955

# %%
#Converting the features into a polynomial equations
from sklearn.preprocessing import PolynomialFeatures
p=PolynomialFeatures(degree=2)
x_poly=p.fit_transform(x)

# %%
from sklearn.preprocessing import PolynomialFeatures
p=PolynomialFeatures(degree=2)
x_poly=p.fit_transform(x)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score,mean_squared_error
print(mean_squared_error(y,lr.predict(x_poly)))
r2_score(y,lr.predict(x_poly))
# Out:
# 54333827847.888306
# 0.5968773620459124

# %%
from sklearn.preprocessing import PolynomialFeatures
p=PolynomialFeatures(degree=2)
x_poly=p.fit_transform(x)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score,mean_squared_error
print(mean_squared_error(y,lr.predict(x_poly)))
r2_score(y,lr.predict(x_poly))
# Out:
# 54333827847.888306
# 0.5968773620459124

# %%
import matplotlib.pyplot as plt
x1_range=np.linspace(min(x.iloc[:,0]),max(x.iloc[:,0]),10)
x2_range=np.linspace(min(x.iloc[:,1]),max(x.iloc[:,1]),10)
x1_grid,x2_grid=np.meshgrid(x1_range,x2_range)
x_grid_poly=p.transform(np.c_[x1_grid.ravel(),x2_grid.ravel()])
y_grid=lr.predict(x_grid_poly).reshape(x1_grid.shape)
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.scatter(x.iloc[:,0],x.iloc[:,1],y)
ax.plot_surface(x1_grid,x2_grid,y_grid)
plt.title("717822I226-KEERTHIGA.S")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# Text(0.5, 0.92, '717822I226-KEERTHIGA.S')
